# %% [markdown]
# #Bölüm 6
# ## Veri goruntuleme
#
# Yöneticiniz, satış ekibinin daha iyi ve yararlı bilgiler elde etmesine yardımcı olmak için veri görselleştirmeleri sağlamanızı istiyor.

# %% [markdown]
# ###Kütüphaneleri İçe Aktarma
#
# Öncelikle gerekli kütüphaneleri içe aktarmanız gerekir.
#
# 📌 Matplotlib ve Pandas kütüphanelerini içe aktarın.

# %%
#Import Matplotlib and Pandas
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ###Matplotlib Temelleri
#
# Görevinize odaklanmadan önce Matplotlib'in temellerini uygulayın.
#
# 📌 Örnek veriler oluşturun:
#    1. X ekseni değerlerinin listesi
#    2. Y ekseni değerlerinin listesi

# %%
#Create a list for the x-axis values
x = [0,2,4,6,8,10,12,14,16]
#Create a list for the y-axis values
y = [ 0,4,16,36,64,100,144,196,256]

# %% [markdown]
# ####Çizgi grafiği
# Farklı grafik türlerinden bazılarını keşfetmek için bu basit verileri kullanın.
#
# 📌 Çizgi grafiği oluşturmak için Matplotlib'in .plot() fonksiyonunu, "Örnek veri - Çizgi grafiği" başlığını eklemek için .title() metodunu kullanın.
#
# 📌 Grafiği görüntülemek için *plt.show()* kullanın.

# %%
#Use the .plot() function to create a line plot
plt.plot(x,y)
#Use the .title() method to add the title
plt.title("Example data - Line plot")
#Display the plot
plt.show()

# %% [markdown]
# ####Dağılım grafiği
#
# Daha sonra, bir dağılım grafiği oluşturmak için aynı verileri kullanın.
#
# 📌 Bir dağılım grafiği oluşturmak için Matplotlib'in .scatter() fonksiyonunu kullanın ve "Örnek veri - Dağılım grafiği" başlığını eklemek için .title() yöntemini kullanın.
#
# 📌 Grafiği görüntülemek için *plt.show()* kullanın.

# %%
#Use the .scatter() function to create a scatter plot
plt.scatter(x,y)
#Use the .title() method to add the title
plt.title("Example data - Line plot")

#Display the plot
plt.show()

# %% [markdown]
# ####Grafik çubuğu
#
# Son olarak, bir çubuk grafik oluşturmak için aynı verileri kullanın.
#
# 📌 Çubuk grafik oluşturmak için Matplotlib'in .bar() fonksiyonunu kullanın ve "Örnek veri - Çubuk grafik" başlığını eklemek için .title() yöntemini kullanın.
#
# 📌 Grafiği görüntülemek için *plt.show()* kullanın.

# %%
#Use the .bar() function to create a bar chart
plt.bar(x,y)

#Use the .title() method to add the title
plt.title("Example data - Line plot")

#Display the chart
plt.show()

# %% [markdown]
# Grafikleri yan yana görmek istediğinize karar veriyorsunuz. Şeklin daha okunaklı olması için her grafiğin farklı bir rengi olmalıdır.
#
# 📌 18x5 boyutunda bir şekil nesnesi oluşturmak için Matplotlib'in .figure() fonksiyonunu ve onun "figsize" argümanını kullanın.
#
# 📌 Yeni oluşturduğunuz üç grafiği şekle eklemek ve her birine bir başlık eklemek için .add_subplot() yöntemini kullanın.
#
#    * 3 grafiğin bulunduğu 1 satır olmalıdır.
#
#    * Her grafiğin rengini değiştirmek için "renk" argümanını kullanın:
#      1. Çizgi grafiği: kırmızı
#      2. Dağılım grafiği: yeşil
#      3. Çubuk grafik: turuncu

# %%
#Create a figure object of the size 18x5
fig =plt.figure(figsize=(18,5))

#Use the .add_subplot() method to add the line plot
first_plot = fig.add_subplot(1,3,1)

#Change the color to red
first_plot.plot(x,y,color = "red")

#Add the title
first_plot.set_title("Example data - Line plot")

#Use the .add_subplot() method to add the scatter plot
second_plot = fig.add_subplot(1,3,2)

#Change the color to green
second_plot.scatter(x,y,color="green")

#Add the title
second_plot.set_title("Example data - Line plot")

#Use the .add_subplot() method to add the bar chart
third_plot = fig.add_subplot(1,3,3)

#Change the color to orange
third_plot.bar(x,y,color = "orange")
#Add the title
third_plot.set_title("Example data - Line plot")
#Display the figure
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ###Satış raporunun görselleştirilmesi
#
# Artık görevinizi üstlenmeye hazırsınız.
#
# Satış ekibi bir rapor oluşturuyor ve sonuçların görselleştirilmesine ihtiyaç duyuyor. Yöneticiniz Rachel, raporu inceleyen kişilerin verileri daha iyi anlayabilmesi için sizden bazı grafikler oluşturmanızı istiyor. Size satış verilerini içeren bir .csv dosyası sunarlar.

# %% [markdown]
# ####Veri Hazırlama
#
# Öncelikle verileri .csv dosyasından almanız gerekir.
#
# 📌 "employee_performans.csv" dosyasını okumak ve bunu "data" değişkenine atamak için .read_csv() fonksiyonunu kullanın.
#
# 📌 Veri kümesinin ne içerdiğini kontrol etmek için .head() işlevini kullanın.

# %%
#Read the data from "employee_performance.csv""
data = pd.read_csv("employee_performance.csv")

#Use the .head() function to check the dataset
data.head()
# Out:
#      Name   Job Type Experience Level    Education  Number of Calls
# 0    Omer  Full-Time           Senior  High School              400  \
# 1  Arnold  Full-Time           Junior   University              150
# 2   Aidan  Full-Time           Senior      College              170
# 3     Sue  Part-Time              Mid  High School              220
# 4     Ben  Full-Time           Junior      College              140
#
#    Average Deal Size  Revenue
# 0                  8     2000
# 1                 10     1000
# 2                 15     2000
# 3                  5     1000
# 4                 22     1600

# %% [markdown]
# ####Eğitim düzeyinin grafiğini çizin
#
# Öncelikle satış ekibinin eğitim seviyesi hakkında bazı öngörüler oluşturuyorsunuz ve pasta grafiğinin faydalı olacağına karar veriyorsunuz. Farklı kategorilerdeki kişi sayısını belirlemeniz gerekiyor.
#
# 📌 Farklı kategorilerdeki kişi sayısını belirlemek için .value_counts() fonksiyonunu kullanın.

# %%
#Use the .value_counts() function to determine the number of people in the different categories
educational_level = data["Education"].value_counts()

#Display the result
educational_level
# Out:
# Education
# College        4
# High School    3
# University     3
# Name: count, dtype: int64

# %% [markdown]
# Ardından "Üniversite", "Lise", "Üniversite" etiketlerini içeren bir pasta grafiği oluşturun.
#
# 📌 Pasta grafiği oluşturmak için .pie() fonksiyonunu ve Pandas Serisinin indekslerini etiket olarak vermek için "labels" argümanını kullanın.

# %%
#Create a pie chart with the labels "College", "High School", "University"
plt.pie(educational_level,labels=educational_level.index)

#Display the chart
plt.show()

# %% [markdown]
# ####Gelir grafiğini çizin
#
# Daha sonra çalışanların elde ettiği gelirin çubuk grafiğini oluşturmanız gerekir.
# Adlar x ekseninde, gelirler ise y ekseninde olmalıdır.
#
# 📌 Gelir değerlerinin çubuk grafiğini oluşturmak için .bar() işlevini kullanın.

# %%
#Create a bar chart with the names on the x-axis and the revenue values on the y-axis
plt.bar(data["Name"],data["Revenue"])

#Display the chart
plt.show()

# %% [markdown]
# Bu durumdaki grafik yalnızca çalışanlar arasındaki karşılaştırmayı gösterir.
#
# Anlaşılabilirliği artırmak için grafiğe "Çağrı sayısı" verilerini eklemeye karar veriyorsunuz.
#
# 📌 "Gelir" ve "Çağrı sayısı" verilerini çubuk grafiğe ekleyin. Verileri etiketlemek için "etiket" bağımsız değişkenini kullanın.
#
# Verileri ayırt etmek için bir gösterge eklemeniz gerekir. Ayrıca ızgara çizgileri eklemek de faydalı olacaktır.
#
# 📌 Izgara çizgileri eklemek için .legend() fonksiyonunu ve .grid() fonksiyonunu kullanarak bir efsane ekleyin.;

# %%
#Create a bar chart with the data "Revenue" and "Number of calls"
plt.bar(data["Name"],data["Revenue"],label = "Revenues")
plt.bar(data["Name"],data["Number of Calls"],label = "Number of calls")

#Add a legend
plt.legend()

#Add grid lines
plt.grid()

#Display the chart
plt.show()
